# %%
import skrf as rf
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *
rf.stylely()

import plot_bands

# %%
# Choke: GRA-RWSM HF Antenna RF RFI Choke Coil Coax - https://www.amazon.ca/Unlock-Optimal-Antenna-Performance-GRA-RWSM/dp/B0CHRVBGH3
plot_bands.plot_bands_comparative(['./data/2025-04-18/Choke', './data/2025-04-18/Antenna'], "SE HF-360 XP w/o choke")
# Out:
# 80 M : 1-Port Network: '80',  3.5-4.0 MHz, 401 pts, z0=[50.+0.j]
# 80 M : 1-Port Network: '80',  3.5-4.0 MHz, 401 pts, z0=[50.+0.j]
# 40 M : 1-Port Network: '40',  7.0-7.3 MHz, 401 pts, z0=[50.+0.j]
# 40 M : 1-Port Network: '40',  7.0-7.3 MHz, 401 pts, z0=[50.+0.j]
# 30 M : 1-Port Network: '30',  10.1-10.15 MHz, 401 pts, z0=[50.+0.j]
# 30 M : 1-Port Network: '30',  10.1-10.15 MHz, 401 pts, z0=[50.+0.j]
# 20 M : 1-Port Network: '20',  14.0-14.35 MHz, 401 pts, z0=[50.+0.j]
# 20 M : 1-Port Network: '20',  14.0-14.35 MHz, 401 pts, z0=[50.+0.j]
# 17 M : 1-Port Network: '17',  18.068-18.168 MHz, 401 pts, z0=[50.+0.j]
# 17 M : 1-Port Network: '17',  18.068-18.168 MHz, 401 pts, z0=[50.+0.j]
# 15 M : 1-Port Network: '15',  21.0-21.45 MHz, 401 pts, z0=[50.+0.j]
# 15 M : 1-Port Network: '15',  21.0-21.45 MHz, 401 pts, z0=[50.+0.j]
# 12 M : 1-Port Network: '12',  24.89-24.99 MHz, 401 pts, z0=[50.+0.j]
# 12 M : 1-Port Network: '12',  24.89-24.99 MHz, 401 pts, z0=[50.+0.j]
# ...

# %%
plot_bands.plot_all_in_one(['./data/2025-04-18/Choke', './data/2025-04-18/Antenna'], 'SE HF-360 XP w/o choke - All band', ['With Choke', 'Just Antenna'])
