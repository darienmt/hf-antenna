# %%
import skrf as rf
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *
rf.stylely()

import plot_bands

# %%
plot_bands.plot_all_in_one(
    ['./data/2025-03-08', './data/2025-04-15', './data/2025-04-18/Choke', './data/2025-04-18/Antenna'], 
    'SE HF-360 XP w/o choke - All band',
    ['Endfed', 'With ground', 'With choke', 'antenna only'])

# %%
plot_bands.plot_bands_comparative(
    ['./data/2025-03-08', './data/2025-04-15', './data/2025-04-18/Choke', './data/2025-04-18/Antenna'], 
    'SE HF-360 XP w/o choke - All band',
    ['Endfed', 'With ground', 'With choke', 'antenna only'])

# %%
plot_bands.plot_bands_comparative(
    [ './data/2025-04-15', './data/2025-04-18/Antenna'], 
    'SE HF-360 XP w/o ground - All band',
    [ 'With ground', 'antenna only'])

# %%
plot_bands.plot_bands_comparative(
    [ './data/2025-04-18/Antenna'], 
    'SE HF-360 XP - All band',
    [ 'antenna only'])
