# %%
import skrf as rf
# %matplotlib inline
from pylab import *
rf.stylely()

# %%
before_tuning = rf.Network('data/nanovna-20250114-023725.s1p')

# %%
before_tuning.plot_s_mag(label='no tuning')

# %%
tuning1=rf.Network('data/nanovna-20250114-151820.s1p')
tuning1.plot_s_db(label='First tuning')

# %%
tuning2 = rf.Network('data/nanovna-20250114-164414.s1p')
tuning1.plot_s_db(label='Second tuning')

# %%
tuning3 = rf.Network('data/nanovna-20250114-165341.s1p')
tuning1.plot_s_db(label='Last tuning')
